# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("D:\\5th semester subjects\\language.csv")

# %%
data
# Out:
#                                                     Text  language
# 0      klement gottwaldi surnukeha palsameeriti ning ...  Estonian
# 1      sebes joseph pereira thomas  på eng the jesuit...   Swedish
# 2      ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เ...      Thai
# 3      விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...     Tamil
# 4      de spons behoort tot het geslacht haliclona en...     Dutch
# ...                                                  ...       ...
# 21995  hors du terrain les années  et  sont des année...    French
# 21996  ใน พศ  หลักจากที่เสด็จประพาสแหลมมลายู ชวา อินเ...      Thai
# 21997  con motivo de la celebración del septuagésimoq...   Spanish
# 21998  年月，當時還只有歲的她在美國出道，以mai-k名義推出首張英文《baby i like》，由...   Chinese
# 21999   aprilie sonda spațială messenger a nasa și-a ...  Romanian
#
# [22000 rows x 2 columns]

# %%
data.duplicated().sum()
# Out:
# 141

# %%
data=data.drop_duplicates(keep='first')

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
data.isnull().sum()
# Out:
# Text        0
# language    0
# dtype: int64

# %%
data['language'].value_counts()
# Out:
# language
# Chinese       1000
# Thai          1000
# English       1000
# Japanese      1000
# Turkish       1000
# Romanian      1000
# Urdu          1000
# Persian       1000
# Korean        1000
# Estonian       999
# Russian        999
# Arabic         998
# Portugese      997
# Spanish        996
# Dutch          996
# Pushto         993
# Swedish        992
# Hindi          990
# French         990
# Tamil          981
# Indonesian     975
# Latin          953
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21859 entries, 0 to 21999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Text      21859 non-null  object
#  1   language  21859 non-null  object
# dtypes: object(2)
# memory usage: 512.3+ KB

# %%
x=np.array(data['Text'])
y=np.array(data['language'])

# %%
x
# Out:
# array(['klement gottwaldi surnukeha palsameeriti ning paigutati mausoleumi surnukeha oli aga liiga hilja ja oskamatult palsameeritud ning hakkas ilmutama lagunemise tundemärke  aastal viidi ta surnukeha mausoleumist ära ja kremeeriti zlíni linn kandis aastatel – nime gottwaldov ukrainas harkivi oblastis kandis zmiivi linn aastatel – nime gotvald',
#        'sebes joseph pereira thomas  på eng the jesuits and the sino-russian treaty of nerchinsk  the diary of thomas pereira bibliotheca instituti historici s i --   rome libris ',
#        'ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เริ่มตั้งแต่ถนนสนามไชยถึงแม่น้ำเจ้าพระยาที่ถนนตก กรุงเทพมหานคร เป็นถนนรุ่นแรกที่ใช้เทคนิคการสร้างแบบตะวันตก ปัจจุบันผ่านพื้นที่เขตพระนคร เขตป้อมปราบศัตรูพ่าย เขตสัมพันธวงศ์ เขตบางรัก เขตสาทร และเขตบางคอแหลม',
#        ...,
# ...

# %%
cv=CountVectorizer()

# %%
x=cv.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=MultinomialNB()
model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
pred=model.predict(x_test)
xpred=model.predict(x_train)

# %%
model.score(x_test,y_test)
# Out:
# 0.9542543458371455

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9542543458371455

# %%
accuracy_score(y_train,xpred)
# Out:
# 0.984159661462801

# %% [raw]
# user=input('Enter your text')
# data=cv.transform([user]).toarray()

# %%
user=input('Enter your text')
data=cv.transform([user]).toarray()
output=model.predict(data)
print(output)
# Out:
# Enter your text hey raj what are you doing
# ['English']

# %% [markdown]
# # this model gives 98% accuracy_score on training data and 95% accuracy on test data it is overfitting condition but its ok i have not do any feature engineering and other data preprocessing tast
# # it can be couse of overfitting

# %% [markdown]
# ### try another model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.9542543458371455

# %%
model.score(x_train,y_train)
# Out:
# 0.984159661462801

# %% [markdown]
# #Here both naive_bayes and kneighbors gives same score
